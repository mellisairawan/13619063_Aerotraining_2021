# %% [markdown]
# # Transonic Airfoil Aerodynamic Coefficients Prediction using Artificial Neural Network

# %% [markdown]
# ##Fill in your answer in "isi jawaban anda!"

# %% [markdown]
# In this notebook, an artificial neural network being modeled to predict the aerodynamic coefficients of an airfoil that flies at a nominal condition of __Mach Number M = 0.729__ where the data of varying M and __angle of attack α__ results in various __lift coefficient Cl__, __drag coefficient Cd__ and the pressure coefficient at the center of the upper surface of the airfoil __Cp__ using _Tensorflow and Keras_.
#
# The data were taken from the following reference: Pramudita Satria Palar, Lavi Rizki Zuhal, and Koji Shimoyama."Gaussian Process Surrogate Model with Composite Kernel Learning for Engineering Design." _AIAA Journal_ 58, no. 4 (2020):1864-1880.
#
# _Notebook made to explore simple Artificial Neural Network, Rafael S_

# %% [markdown]
# ### Importing required packages

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ### Importing Dataset

# %%
#from google.colab import drive
#drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
df = pd.read_csv('transonic_airfoil_data_set.csv').drop(columns = 'No')
df
# Out:
#             M       AoA        Cl        Cd        Cp
# 0    0.727928  2.449037  0.740129  0.013330 -0.911550
# 1    0.736393  2.389265  0.736667  0.015423 -1.218775
# 2    0.731969  2.251332  0.709717  0.013156 -1.122496
# 3    0.735015  2.388274  0.736197  0.014977 -1.214580
# 4    0.725872  2.448004  0.737060  0.012857 -0.697603
# ..        ...       ...       ...       ...       ...
# 961  0.735045  2.165183  0.698091  0.013423 -1.164278
# 962  0.726631  2.204177  0.693080  0.011845 -0.626338
# 963  0.727602  2.113649  0.678026  0.011613 -0.634598
# 964  0.738150  2.251622  0.715140  0.014969 -1.198659
# 965  0.728880  2.491825  0.749115  0.013877 -1.037020
#
# [966 rows x 5 columns]

# %% [markdown]
# ### Data Plot

# %% [markdown]
# Plotting the data to have a better visualization of our data distribution and linearity.

# %% [markdown]
# #### Lift Coefficient Cl Plot

# %%
figcl = plt.figure(figsize = [6,6])
clplot = Axes3D(figcl)
clplot.scatter(df['M'], df['AoA'], df['Cl'])
clplot.set_xlabel('Mach Number')
clplot.set_ylabel('Angle of Attack (degree)')
clplot.set_zlabel('Cl')
plt.show()

plt.scatter(df['M'], df['Cl'], alpha = 0.3)
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cl'], alpha = 0.3)
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.show()

# %% [markdown]
# #### Drag Coefficient Cd Plot

# %%
figcd = plt.figure(figsize = [6,6])
cdplot = Axes3D(figcd)
cdplot.scatter(df['M'], df['AoA'], df['Cd'], c = 'r', alpha = 0.3)
cdplot.set_xlabel('Mach Number')
cdplot.set_ylabel('Angle of Attack (degree)')
cdplot.set_zlabel('Cd')
plt.show()

plt.scatter(df['M'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cd'], alpha = 0.2, c = 'r')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.show()

# %% [markdown]
# #### Pressure Coefficient Cp Plot

# %%
figcp = plt.figure(figsize = [6,6])
cpplot = Axes3D(figcp)
cpplot.scatter(df['M'], df['AoA'], df['Cp'], c = 'g')
cpplot.set_xlabel('Mach Number')
cpplot.set_ylabel('Angle of Attack (degree)')
cpplot.set_zlabel('Cp')
plt.show()

plt.scatter(df['M'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Mach Number')
plt.ylabel('Cp')
plt.title('Cp vs Mach Number')
plt.show()

plt.scatter(df['AoA'], df['Cp'], alpha = 0.3, c = 'g')
plt.xlabel('Angle of Attack (degree)')
plt.ylabel('Cp')
plt.title('Cp vs AoA')
plt.show()

# %% [markdown]
# ### Correlation Coefficient

# %% [markdown]
# Checking the Pearson's correlation coefficient to measure the statistical relationship, or association, between the variables.

# %%
df_heatmap = sns.heatmap(df.corr(), annot = True, cmap = 'coolwarm')

# %% [markdown]
# ### Input and Output Data
# Defining the input data and the output data.

# %%
X = df.loc[:, ["M", "AoA"]]
y = df.loc[:, ["Cl", "Cd", "Cp"]]

# %%
X #Input Data
# Out:
#             M       AoA
# 0    0.727928  2.449037
# 1    0.736393  2.389265
# 2    0.731969  2.251332
# 3    0.735015  2.388274
# 4    0.725872  2.448004
# ..        ...       ...
# 961  0.735045  2.165183
# 962  0.726631  2.204177
# 963  0.727602  2.113649
# 964  0.738150  2.251622
# 965  0.728880  2.491825
#
# [966 rows x 2 columns]

# %%
y #Output Data
# Out:
#            Cl        Cd        Cp
# 0    0.740129  0.013330 -0.911550
# 1    0.736667  0.015423 -1.218775
# 2    0.709717  0.013156 -1.122496
# 3    0.736197  0.014977 -1.214580
# 4    0.737060  0.012857 -0.697603
# ..        ...       ...       ...
# 961  0.698091  0.013423 -1.164278
# 962  0.693080  0.011845 -0.626338
# 963  0.678026  0.011613 -0.634598
# 964  0.715140  0.014969 -1.198659
# 965  0.749115  0.013877 -1.037020
#
# [966 rows x 3 columns]

# %% [markdown]
# ### Dataset Split (Training and Validation Data)
# Splitting the dataset by random and evenly distributed for the training and validation dataset.

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 29)

# %% [markdown]
# Plotting to visualize the dataset split result.

# %%
# Creating figure
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(X_train['M'], X_train['AoA'], y_train['Cl'], color = "green", alpha=0.3, label='Train Data')
visual_split.scatter3D(X_test['M'], X_test['AoA'], y_test['Cl'], color = "red",alpha=0.5, label='Test Data')
plt.title("Train and Test Dataset")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

# %% [markdown]
# ## Normalizing The Data

# %% [markdown]
# Normalization ensures that the magnitude of the values that a feature assumes are more or less the same.

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
scalery = MinMaxScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

y_train = scalery.fit_transform(y_train)
y_test = scalery.transform(y_test)

# %% [markdown]
# ## Modeling The Artificial Neural Network

# %% [markdown]
# The activation function for the hidden layer of the network is using the Rectified Linear Unit (ReLU) function as it is a simple, fast and observed to converge much more quickly and reliably.
#
# The Dropout algorithm is commented out as it doesn't provide improvements after a few trainings, and early stopping method is being used instead to avoid overfitting our neural network to the dataset.
#
# The optimizer is the adam optimizer as it provides an adaptive learning rate to optimize better.

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation,Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# %%
NNmodel = Sequential()

NNmodel.add(Dense(30, activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(20, activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))
NNmodel.add(Dense(10, activation='relu')) #Hidden Layer
#NNmodel.add(Dropout(0.2))

NNmodel.add(Dense(units = 3, activation='linear')) #Output Layer

NNmodel.compile(loss='mse', optimizer='adam')

# %% [markdown]
# ### Early Stopping

# %% [markdown]
# To avoid overfitting during the training of the neural network, early stopping method is being added. Early stopping is a form of regularization used to avoid overfitting when training a learner with an iterative method.

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=50)

# %% [markdown]
# ### Training The Artificial Neural Network

# %%
NNmodel.fit(x=X_train, y=y_train, epochs=500, validation_data=(X_test,y_test), callbacks=[early_stop])
# Out:
# Epoch 1/500
# 23/23 [==============================] - 1s 11ms/step - loss: 0.2095 - val_loss: 0.1675
# Epoch 2/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1478 - val_loss: 0.1346
# Epoch 3/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.1218 - val_loss: 0.1107
# Epoch 4/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0982 - val_loss: 0.0850
# Epoch 5/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0734 - val_loss: 0.0608
# Epoch 6/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0529 - val_loss: 0.0444
# Epoch 7/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0416 - val_loss: 0.0373
# Epoch 8/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0351 - val_loss: 0.0320
# Epoch 9/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0293 - val_loss: 0.0254
# Epoch 10/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0237 - val_loss: 0.0202
# Epoch 11/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0182 - val_loss: 0.0158
# Epoch 12/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0140 - val_loss: 0.0125
# Epoch 13/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0112 - val_loss: 0.0100
# Epoch 14/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0092 - val_loss: 0.0086
# Epoch 15/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0080 - val_loss: 0.0076
# Epoch 16/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0072 - val_loss: 0.0073
# Epoch 17/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0066 - val_loss: 0.0062
# Epoch 18/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0059 - val_loss: 0.0057
# Epoch 19/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0054 - val_loss: 0.0050
# Epoch 20/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0049 - val_loss: 0.0046
# Epoch 21/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0045 - val_loss: 0.0042
# Epoch 22/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0040 - val_loss: 0.0040
# Epoch 23/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0038 - val_loss: 0.0035
# Epoch 24/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0034 - val_loss: 0.0033
# Epoch 25/500
# 23/23 [==============================] - 0s 4ms/step - loss: 0.0031 - val_loss: 0.0028
# Epoch 26/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0027 - val_loss: 0.0025
# Epoch 27/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0025 - val_loss: 0.0024
# Epoch 28/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0023 - val_loss: 0.0022
# Epoch 29/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0021 - val_loss: 0.0021
# Epoch 30/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0019 - val_loss: 0.0020
# Epoch 31/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0018 - val_loss: 0.0017
# Epoch 32/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0017 - val_loss: 0.0016
# Epoch 33/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0016 - val_loss: 0.0016
# Epoch 34/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0015 - val_loss: 0.0015
# Epoch 35/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 36/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0014 - val_loss: 0.0014
# Epoch 37/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0014
# Epoch 38/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 39/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 40/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 41/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 42/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 43/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 44/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 45/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 46/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 47/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 48/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 49/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 50/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 51/500
# 23/23 [==============================] - 0s 3ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 52/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.8972e-04 - val_loss: 0.0011
# Epoch 53/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.7979e-04 - val_loss: 0.0011
# Epoch 54/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.6574e-04 - val_loss: 0.0011
# Epoch 55/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.5336e-04 - val_loss: 0.0011
# Epoch 56/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.5096e-04 - val_loss: 0.0011
# Epoch 57/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.3577e-04 - val_loss: 0.0010
# Epoch 58/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.2361e-04 - val_loss: 0.0010
# Epoch 59/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.1666e-04 - val_loss: 0.0010
# Epoch 60/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.1249e-04 - val_loss: 0.0010
# Epoch 61/500
# 23/23 [==============================] - 0s 21ms/step - loss: 8.9525e-04 - val_loss: 0.0010
# Epoch 62/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.9507e-04 - val_loss: 9.9905e-04
# Epoch 63/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.8411e-04 - val_loss: 9.8605e-04
# Epoch 64/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.7269e-04 - val_loss: 9.8119e-04
# Epoch 65/500
# 23/23 [==============================] - 0s 4ms/step - loss: 8.6241e-04 - val_loss: 9.8610e-04
# Epoch 66/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.5408e-04 - val_loss: 9.6181e-04
# Epoch 67/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.4291e-04 - val_loss: 9.5996e-04
# Epoch 68/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.3540e-04 - val_loss: 9.5279e-04
# Epoch 69/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.2179e-04 - val_loss: 9.3932e-04
# Epoch 70/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.1584e-04 - val_loss: 9.6419e-04
# Epoch 71/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.2180e-04 - val_loss: 9.3057e-04
# Epoch 72/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.0206e-04 - val_loss: 9.1413e-04
# Epoch 73/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8840e-04 - val_loss: 9.0651e-04
# Epoch 74/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8160e-04 - val_loss: 8.9479e-04
# Epoch 75/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.6562e-04 - val_loss: 8.8512e-04
# Epoch 76/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.5817e-04 - val_loss: 8.7220e-04
# Epoch 77/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.4874e-04 - val_loss: 8.7487e-04
# Epoch 78/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.4349e-04 - val_loss: 8.6177e-04
# Epoch 79/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.3414e-04 - val_loss: 8.5469e-04
# Epoch 80/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.2331e-04 - val_loss: 8.5263e-04
# Epoch 81/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.1769e-04 - val_loss: 8.2896e-04
# Epoch 82/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.0984e-04 - val_loss: 8.2804e-04
# Epoch 83/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.9757e-04 - val_loss: 8.1101e-04
# Epoch 84/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.8756e-04 - val_loss: 8.0482e-04
# Epoch 85/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.9119e-04 - val_loss: 8.0101e-04
# Epoch 86/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.7019e-04 - val_loss: 7.8291e-04
# Epoch 87/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.6426e-04 - val_loss: 7.7575e-04
# Epoch 88/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.5396e-04 - val_loss: 7.6460e-04
# Epoch 89/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.4718e-04 - val_loss: 7.5481e-04
# Epoch 90/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.4040e-04 - val_loss: 7.4688e-04
# Epoch 91/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.2190e-04 - val_loss: 7.3425e-04
# Epoch 92/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.0862e-04 - val_loss: 7.2928e-04
# Epoch 93/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.0403e-04 - val_loss: 7.1589e-04
# Epoch 94/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.8753e-04 - val_loss: 7.0732e-04
# Epoch 95/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.8043e-04 - val_loss: 7.0345e-04
# Epoch 96/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7585e-04 - val_loss: 6.8405e-04
# Epoch 97/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.6380e-04 - val_loss: 7.0043e-04
# Epoch 98/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.5976e-04 - val_loss: 6.6597e-04
# Epoch 99/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.4315e-04 - val_loss: 6.5665e-04
# Epoch 100/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3355e-04 - val_loss: 6.4817e-04
# Epoch 101/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3394e-04 - val_loss: 6.4968e-04
# Epoch 102/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.2673e-04 - val_loss: 6.2260e-04
# Epoch 103/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.0795e-04 - val_loss: 6.1183e-04
# Epoch 104/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9926e-04 - val_loss: 6.0584e-04
# Epoch 105/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9479e-04 - val_loss: 6.0038e-04
# Epoch 106/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.8841e-04 - val_loss: 5.8898e-04
# Epoch 107/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7555e-04 - val_loss: 5.8409e-04
# Epoch 108/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.6071e-04 - val_loss: 5.8311e-04
# Epoch 109/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5241e-04 - val_loss: 5.6169e-04
# Epoch 110/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5019e-04 - val_loss: 5.4961e-04
# Epoch 111/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3044e-04 - val_loss: 5.5440e-04
# Epoch 112/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4236e-04 - val_loss: 5.5579e-04
# Epoch 113/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3016e-04 - val_loss: 5.1764e-04
# Epoch 114/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0630e-04 - val_loss: 5.0371e-04
# Epoch 115/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9070e-04 - val_loss: 4.8245e-04
# Epoch 116/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8225e-04 - val_loss: 4.7893e-04
# Epoch 117/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8260e-04 - val_loss: 4.6596e-04
# Epoch 118/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7196e-04 - val_loss: 4.5419e-04
# Epoch 119/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5628e-04 - val_loss: 4.3899e-04
# Epoch 120/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5082e-04 - val_loss: 4.3375e-04
# Epoch 121/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.4113e-04 - val_loss: 4.2154e-04
# Epoch 122/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3465e-04 - val_loss: 4.1522e-04
# Epoch 123/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.3138e-04 - val_loss: 4.0780e-04
# Epoch 124/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.2517e-04 - val_loss: 3.9844e-04
# Epoch 125/500
# 23/23 [==============================] - 0s 4ms/step - loss: 3.0439e-04 - val_loss: 3.7912e-04
# Epoch 126/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.9306e-04 - val_loss: 3.7193e-04
# Epoch 127/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.8805e-04 - val_loss: 3.5947e-04
# Epoch 128/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.7844e-04 - val_loss: 3.5032e-04
# Epoch 129/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.7053e-04 - val_loss: 3.4853e-04
# Epoch 130/500
# 23/23 [==============================] - 0s 4ms/step - loss: 2.6987e-04 - val_loss: 3.3433e-04
# Epoch 131/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.5956e-04 - val_loss: 3.3115e-04
# Epoch 132/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.4848e-04 - val_loss: 3.1970e-04
# Epoch 133/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.4798e-04 - val_loss: 3.1150e-04
# Epoch 134/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.3858e-04 - val_loss: 2.9561e-04
# Epoch 135/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.2783e-04 - val_loss: 2.8769e-04
# Epoch 136/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.2543e-04 - val_loss: 2.8832e-04
# Epoch 137/500
# 23/23 [==============================] - 0s 4ms/step - loss: 2.2118e-04 - val_loss: 2.7422e-04
# Epoch 138/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.1231e-04 - val_loss: 2.7909e-04
# Epoch 139/500
# 23/23 [==============================] - 0s 4ms/step - loss: 2.0802e-04 - val_loss: 2.7724e-04
# Epoch 140/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.0147e-04 - val_loss: 2.4918e-04
# Epoch 141/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.9160e-04 - val_loss: 2.5277e-04
# Epoch 142/500
# 23/23 [==============================] - 0s 3ms/step - loss: 2.0122e-04 - val_loss: 2.4800e-04
# Epoch 143/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.9140e-04 - val_loss: 2.4325e-04
# Epoch 144/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.8095e-04 - val_loss: 2.2751e-04
# Epoch 145/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6640e-04 - val_loss: 2.1636e-04
# Epoch 146/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.6622e-04 - val_loss: 2.2500e-04
# Epoch 147/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.7135e-04 - val_loss: 2.1203e-04
# Epoch 148/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.5492e-04 - val_loss: 2.0062e-04
# Epoch 149/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4682e-04 - val_loss: 1.8871e-04
# Epoch 150/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.4196e-04 - val_loss: 1.9879e-04
# Epoch 151/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3976e-04 - val_loss: 1.8295e-04
# Epoch 152/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3793e-04 - val_loss: 1.9686e-04
# Epoch 153/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.3191e-04 - val_loss: 1.8107e-04
# Epoch 154/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2736e-04 - val_loss: 1.7930e-04
# Epoch 155/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2552e-04 - val_loss: 1.6641e-04
# Epoch 156/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1947e-04 - val_loss: 1.5793e-04
# Epoch 157/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1533e-04 - val_loss: 1.5230e-04
# Epoch 158/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.2443e-04 - val_loss: 1.5923e-04
# Epoch 159/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1549e-04 - val_loss: 1.6460e-04
# Epoch 160/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.1535e-04 - val_loss: 1.4202e-04
# Epoch 161/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.0313e-04 - val_loss: 1.3718e-04
# Epoch 162/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.9816e-05 - val_loss: 1.3540e-04
# Epoch 163/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.0255e-04 - val_loss: 1.3140e-04
# Epoch 164/500
# 23/23 [==============================] - 0s 3ms/step - loss: 1.0278e-04 - val_loss: 1.3511e-04
# Epoch 165/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.6447e-05 - val_loss: 1.2838e-04
# Epoch 166/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.3302e-05 - val_loss: 1.2167e-04
# Epoch 167/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.6948e-05 - val_loss: 1.2091e-04
# Epoch 168/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.9376e-05 - val_loss: 1.1534e-04
# Epoch 169/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.9444e-05 - val_loss: 1.2757e-04
# Epoch 170/500
# 23/23 [==============================] - 0s 3ms/step - loss: 9.4538e-05 - val_loss: 1.1189e-04
# Epoch 171/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.4540e-05 - val_loss: 1.0805e-04
# Epoch 172/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.1470e-05 - val_loss: 1.0796e-04
# Epoch 173/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.2797e-05 - val_loss: 1.0854e-04
# Epoch 174/500
# 23/23 [==============================] - 0s 3ms/step - loss: 8.2174e-05 - val_loss: 1.0746e-04
# Epoch 175/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.6742e-05 - val_loss: 1.0710e-04
# Epoch 176/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8645e-05 - val_loss: 1.1120e-04
# Epoch 177/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.9850e-05 - val_loss: 1.0173e-04
# Epoch 178/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.7106e-05 - val_loss: 1.1050e-04
# Epoch 179/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8695e-05 - val_loss: 1.0147e-04
# Epoch 180/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.2951e-05 - val_loss: 1.0560e-04
# Epoch 181/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8489e-05 - val_loss: 9.8155e-05
# Epoch 182/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.3921e-05 - val_loss: 9.3400e-05
# Epoch 183/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.8466e-05 - val_loss: 9.5571e-05
# Epoch 184/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.0212e-05 - val_loss: 9.0838e-05
# Epoch 185/500
# 23/23 [==============================] - 0s 4ms/step - loss: 6.9060e-05 - val_loss: 9.2024e-05
# Epoch 186/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.1996e-05 - val_loss: 8.8642e-05
# Epoch 187/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.3493e-05 - val_loss: 8.9146e-05
# Epoch 188/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.8632e-05 - val_loss: 8.2784e-05
# Epoch 189/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.6127e-05 - val_loss: 1.0459e-04
# Epoch 190/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.8098e-05 - val_loss: 8.8375e-05
# Epoch 191/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.0034e-05 - val_loss: 8.5306e-05
# Epoch 192/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.5379e-05 - val_loss: 8.2869e-05
# Epoch 193/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.6454e-05 - val_loss: 8.2618e-05
# Epoch 194/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.4537e-05 - val_loss: 9.0778e-05
# Epoch 195/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.7575e-05 - val_loss: 8.3175e-05
# Epoch 196/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.3124e-05 - val_loss: 8.1697e-05
# Epoch 197/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.4206e-05 - val_loss: 8.6696e-05
# Epoch 198/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.6734e-05 - val_loss: 8.1981e-05
# Epoch 199/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.6063e-05 - val_loss: 1.1592e-04
# Epoch 200/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.6272e-05 - val_loss: 8.2125e-05
# Epoch 201/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.7006e-05 - val_loss: 8.0713e-05
# Epoch 202/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7098e-05 - val_loss: 7.5709e-05
# Epoch 203/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.9760e-05 - val_loss: 7.9991e-05
# Epoch 204/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.2774e-05 - val_loss: 8.3193e-05
# Epoch 205/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.8208e-05 - val_loss: 7.4159e-05
# Epoch 206/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3572e-05 - val_loss: 7.2547e-05
# Epoch 207/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.6436e-05 - val_loss: 7.9720e-05
# Epoch 208/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.1491e-05 - val_loss: 8.4104e-05
# Epoch 209/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.6578e-05 - val_loss: 7.5311e-05
# Epoch 210/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3874e-05 - val_loss: 6.7808e-05
# Epoch 211/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.5552e-05 - val_loss: 9.2337e-05
# Epoch 212/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3806e-05 - val_loss: 7.0900e-05
# Epoch 213/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3468e-05 - val_loss: 6.8086e-05
# Epoch 214/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.5318e-05 - val_loss: 6.8322e-05
# Epoch 215/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7627e-05 - val_loss: 1.0127e-04
# Epoch 216/500
# 23/23 [==============================] - 0s 3ms/step - loss: 7.4183e-05 - val_loss: 1.0675e-04
# Epoch 217/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.2088e-05 - val_loss: 6.7442e-05
# Epoch 218/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.9224e-05 - val_loss: 6.3880e-05
# Epoch 219/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1186e-05 - val_loss: 6.8502e-05
# Epoch 220/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.3732e-05 - val_loss: 6.6009e-05
# Epoch 221/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.8258e-05 - val_loss: 6.5492e-05
# Epoch 222/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9875e-05 - val_loss: 6.2902e-05
# Epoch 223/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9814e-05 - val_loss: 6.4533e-05
# Epoch 224/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.6401e-05 - val_loss: 6.4248e-05
# Epoch 225/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.2705e-05 - val_loss: 6.1745e-05
# Epoch 226/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1111e-05 - val_loss: 6.3818e-05
# Epoch 227/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1533e-05 - val_loss: 6.1890e-05
# Epoch 228/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.0773e-05 - val_loss: 6.0367e-05
# Epoch 229/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.2739e-05 - val_loss: 6.1087e-05
# Epoch 230/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9914e-05 - val_loss: 5.7387e-05
# Epoch 231/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.2622e-05 - val_loss: 5.6618e-05
# Epoch 232/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.4826e-05 - val_loss: 7.4564e-05
# Epoch 233/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.4135e-05 - val_loss: 5.8170e-05
# Epoch 234/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7803e-05 - val_loss: 5.6566e-05
# Epoch 235/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.0225e-05 - val_loss: 6.1660e-05
# Epoch 236/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.4799e-05 - val_loss: 6.8473e-05
# Epoch 237/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.2315e-05 - val_loss: 7.0135e-05
# Epoch 238/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.5207e-05 - val_loss: 5.5964e-05
# Epoch 239/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.2368e-05 - val_loss: 5.3982e-05
# Epoch 240/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4476e-05 - val_loss: 5.8156e-05
# Epoch 241/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9152e-05 - val_loss: 5.2069e-05
# Epoch 242/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5738e-05 - val_loss: 5.7159e-05
# Epoch 243/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7197e-05 - val_loss: 5.7029e-05
# Epoch 244/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.0843e-05 - val_loss: 4.9979e-05
# Epoch 245/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1896e-05 - val_loss: 7.5499e-05
# Epoch 246/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1111e-05 - val_loss: 5.5485e-05
# Epoch 247/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.1537e-05 - val_loss: 5.9458e-05
# Epoch 248/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3989e-05 - val_loss: 4.9030e-05
# Epoch 249/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1560e-05 - val_loss: 5.5145e-05
# Epoch 250/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3929e-05 - val_loss: 6.5808e-05
# Epoch 251/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4097e-05 - val_loss: 6.0164e-05
# Epoch 252/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5627e-05 - val_loss: 5.2807e-05
# Epoch 253/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.6357e-05 - val_loss: 6.1893e-05
# Epoch 254/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9517e-05 - val_loss: 5.7553e-05
# Epoch 255/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5825e-05 - val_loss: 5.4622e-05
# Epoch 256/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5726e-05 - val_loss: 5.5996e-05
# Epoch 257/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.8215e-05 - val_loss: 4.9812e-05
# Epoch 258/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2026e-05 - val_loss: 5.6416e-05
# Epoch 259/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4636e-05 - val_loss: 5.3289e-05
# Epoch 260/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0270e-05 - val_loss: 5.0096e-05
# Epoch 261/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1797e-05 - val_loss: 5.1809e-05
# Epoch 262/500
# 23/23 [==============================] - 0s 4ms/step - loss: 4.9277e-05 - val_loss: 5.7477e-05
# Epoch 263/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7828e-05 - val_loss: 4.8340e-05
# Epoch 264/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1541e-05 - val_loss: 5.1677e-05
# Epoch 265/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5406e-05 - val_loss: 6.1304e-05
# Epoch 266/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9861e-05 - val_loss: 5.1101e-05
# Epoch 267/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5591e-05 - val_loss: 6.2981e-05
# Epoch 268/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3198e-05 - val_loss: 5.3106e-05
# Epoch 269/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2703e-05 - val_loss: 4.9187e-05
# Epoch 270/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0517e-05 - val_loss: 7.1962e-05
# Epoch 271/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3539e-05 - val_loss: 5.3763e-05
# Epoch 272/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2246e-05 - val_loss: 4.9416e-05
# Epoch 273/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7376e-05 - val_loss: 7.5181e-05
# Epoch 274/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5180e-05 - val_loss: 4.8636e-05
# Epoch 275/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1992e-05 - val_loss: 5.2776e-05
# Epoch 276/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1304e-05 - val_loss: 5.5862e-05
# Epoch 277/500
# 23/23 [==============================] - 0s 4ms/step - loss: 5.1296e-05 - val_loss: 5.1736e-05
# Epoch 278/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.7313e-05 - val_loss: 5.3358e-05
# Epoch 279/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4113e-05 - val_loss: 5.5528e-05
# Epoch 280/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1796e-05 - val_loss: 5.3538e-05
# Epoch 281/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.6015e-05 - val_loss: 7.4262e-05
# Epoch 282/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5458e-05 - val_loss: 4.7995e-05
# Epoch 283/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7683e-05 - val_loss: 5.4196e-05
# Epoch 284/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.5705e-05 - val_loss: 7.8101e-05
# Epoch 285/500
# 23/23 [==============================] - 0s 3ms/step - loss: 6.9073e-05 - val_loss: 5.1744e-05
# Epoch 286/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.8899e-05 - val_loss: 4.7923e-05
# Epoch 287/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1489e-05 - val_loss: 5.3146e-05
# Epoch 288/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2605e-05 - val_loss: 4.9225e-05
# Epoch 289/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2869e-05 - val_loss: 5.3803e-05
# Epoch 290/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4152e-05 - val_loss: 4.5774e-05
# Epoch 291/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8415e-05 - val_loss: 4.9162e-05
# Epoch 292/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2748e-05 - val_loss: 6.7743e-05
# Epoch 293/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4939e-05 - val_loss: 4.7772e-05
# Epoch 294/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0374e-05 - val_loss: 4.8417e-05
# Epoch 295/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9716e-05 - val_loss: 5.1569e-05
# Epoch 296/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9162e-05 - val_loss: 5.7521e-05
# Epoch 297/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3133e-05 - val_loss: 5.6255e-05
# Epoch 298/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9284e-05 - val_loss: 5.0996e-05
# Epoch 299/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3048e-05 - val_loss: 4.5433e-05
# Epoch 300/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7233e-05 - val_loss: 4.5028e-05
# Epoch 301/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2784e-05 - val_loss: 6.4716e-05
# Epoch 302/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9865e-05 - val_loss: 5.3815e-05
# Epoch 303/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6782e-05 - val_loss: 5.5239e-05
# Epoch 304/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.8151e-05 - val_loss: 6.3104e-05
# Epoch 305/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.6545e-05 - val_loss: 7.5821e-05
# Epoch 306/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.5753e-05 - val_loss: 4.3431e-05
# Epoch 307/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6447e-05 - val_loss: 5.4771e-05
# Epoch 308/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1092e-05 - val_loss: 4.7517e-05
# Epoch 309/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8549e-05 - val_loss: 5.5982e-05
# Epoch 310/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8084e-05 - val_loss: 4.7378e-05
# Epoch 311/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8603e-05 - val_loss: 5.3234e-05
# Epoch 312/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4303e-05 - val_loss: 4.8582e-05
# Epoch 313/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1999e-05 - val_loss: 4.1961e-05
# Epoch 314/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2272e-05 - val_loss: 4.1765e-05
# Epoch 315/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2236e-05 - val_loss: 5.5212e-05
# Epoch 316/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1847e-05 - val_loss: 5.4823e-05
# Epoch 317/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4719e-05 - val_loss: 4.9954e-05
# Epoch 318/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9542e-05 - val_loss: 4.5586e-05
# Epoch 319/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1753e-05 - val_loss: 7.0867e-05
# Epoch 320/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2247e-05 - val_loss: 4.7802e-05
# Epoch 321/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6842e-05 - val_loss: 4.5320e-05
# Epoch 322/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6717e-05 - val_loss: 4.7214e-05
# Epoch 323/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0442e-05 - val_loss: 5.4820e-05
# Epoch 324/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2692e-05 - val_loss: 4.6303e-05
# Epoch 325/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.9453e-05 - val_loss: 5.7975e-05
# Epoch 326/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3841e-05 - val_loss: 5.6388e-05
# Epoch 327/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.3903e-05 - val_loss: 4.4519e-05
# Epoch 328/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7267e-05 - val_loss: 4.4884e-05
# Epoch 329/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0763e-05 - val_loss: 6.1437e-05
# Epoch 330/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4644e-05 - val_loss: 4.3964e-05
# Epoch 331/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7969e-05 - val_loss: 5.5364e-05
# Epoch 332/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8669e-05 - val_loss: 4.5935e-05
# Epoch 333/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8935e-05 - val_loss: 4.9616e-05
# Epoch 334/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8992e-05 - val_loss: 4.7753e-05
# Epoch 335/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5099e-05 - val_loss: 4.9954e-05
# Epoch 336/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.8260e-05 - val_loss: 4.3970e-05
# Epoch 337/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5521e-05 - val_loss: 4.3789e-05
# Epoch 338/500
# 23/23 [==============================] - 0s 4ms/step - loss: 3.5649e-05 - val_loss: 4.4508e-05
# Epoch 339/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.7372e-05 - val_loss: 4.5481e-05
# Epoch 340/500
# 23/23 [==============================] - 0s 4ms/step - loss: 4.0585e-05 - val_loss: 4.7845e-05
# Epoch 341/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6195e-05 - val_loss: 6.2258e-05
# Epoch 342/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.0564e-05 - val_loss: 5.7183e-05
# Epoch 343/500
# 23/23 [==============================] - 0s 4ms/step - loss: 3.8076e-05 - val_loss: 5.4973e-05
# Epoch 344/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2756e-05 - val_loss: 4.3911e-05
# Epoch 345/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.4717e-05 - val_loss: 6.0388e-05
# Epoch 346/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.0639e-05 - val_loss: 4.9000e-05
# Epoch 347/500
# 23/23 [==============================] - 0s 4ms/step - loss: 4.1624e-05 - val_loss: 5.3707e-05
# Epoch 348/500
# 23/23 [==============================] - 0s 4ms/step - loss: 4.0990e-05 - val_loss: 4.8233e-05
# Epoch 349/500
# 23/23 [==============================] - 0s 4ms/step - loss: 3.7703e-05 - val_loss: 4.6507e-05
# Epoch 350/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6175e-05 - val_loss: 4.3537e-05
# Epoch 351/500
# 23/23 [==============================] - 0s 4ms/step - loss: 3.9559e-05 - val_loss: 4.4832e-05
# Epoch 352/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.9531e-05 - val_loss: 7.5663e-05
# Epoch 353/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.0398e-05 - val_loss: 5.3508e-05
# Epoch 354/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.2566e-05 - val_loss: 4.5870e-05
# Epoch 355/500
# 23/23 [==============================] - 0s 4ms/step - loss: 3.7298e-05 - val_loss: 5.2349e-05
# Epoch 356/500
# 23/23 [==============================] - 0s 4ms/step - loss: 4.2357e-05 - val_loss: 4.8545e-05
# Epoch 357/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.4649e-05 - val_loss: 5.8156e-05
# Epoch 358/500
# 23/23 [==============================] - 0s 3ms/step - loss: 5.7884e-05 - val_loss: 4.9633e-05
# Epoch 359/500
# 23/23 [==============================] - 0s 3ms/step - loss: 4.1104e-05 - val_loss: 4.3346e-05
# Epoch 360/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.4521e-05 - val_loss: 4.6477e-05
# Epoch 361/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.6211e-05 - val_loss: 4.4708e-05
# Epoch 362/500
# 23/23 [==============================] - 0s 3ms/step - loss: 3.5681e-05 - val_loss: 4.9380e-05
# Epoch 363/500
# 23/23 [==============================] - 0s 4ms/step - loss: 4.1582e-05 - val_loss: 4.8211e-05
# Epoch 364/500
# 23/23 [==============================] - 0s 4ms/step - loss: 4.0329e-05 - val_loss: 5.8518e-05
# Epoch 00364: early stopping

# %% [markdown]
# ### Plotting The Losses During Training

# %%
losses = pd.DataFrame(NNmodel.history.history)
plt.grid()
plt.yscale("log")
plt.plot(losses['loss'], label='train loss')
plt.plot(losses['val_loss'], label='validation loss')
plt.legend()
losses[['loss', 'val_loss']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Predicting On The Test Dataset

# %%
predictions = NNmodel.predict(X_test)

# %%
predictions = scalery.inverse_transform(predictions)
y_test = scalery.inverse_transform(y_test)

# %% [markdown]
# ### Mean Squared Error and Mean Absolute Error of the Prediction Results

# %%
mse_cl = mean_squared_error(y_test[:,0], predictions[:,0])
print(f"Mean Squared Error for Cl: {mse_cl}")
mae_cl = np.sum(np.absolute(y_test[:,0]- predictions[:,0]))/len(y_test)
print(f"Mean Absolute Error for Cl: {mae_cl}\n")
mse_cd = mean_squared_error(y_test[:,1], predictions[:,1])
print(f"Mean Squared Error for Cd: {mse_cd}")
mae_cd = np.sum(np.absolute(y_test[:,1]- predictions[:,1]))/len(y_test)
print(f"Mean Absolute Error for Cd: {mae_cd}\n")
mse_cp = mean_squared_error(y_test[:,2], predictions[:,2])
print(f"Mean Squared Error for Cp: {mse_cp}")
mae_cp = np.sum(np.absolute(y_test[:,2]- predictions[:,2]))/len(y_test)
print(f"Mean Absolute Error for Cp: {mae_cp}\n")
# Out:
# Mean Squared Error for Cl: 3.287859716565046e-05
# Mean Absolute Error for Cl: 0.004298301071600399
#
# Mean Squared Error for Cd: 4.5354672604605306e-05
# Mean Absolute Error for Cd: 0.004707404146483092
#
# Mean Squared Error for Cp: 9.732138156353076e-05
# Mean Absolute Error for Cp: 0.007843538050267546

# %% [markdown]
# ### Predictions vs Ground Truth Plots

# %%
###############################Cl
# Creating figure Cl
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.title("Cl Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cl')
plt.title('Cl vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,0], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,0], color = "blue", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cl')
plt.title('Cl vs AoA')
plt.legend()
plt.show()

##############################Cd
# Creating figure Cd
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.title("Cd Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,1], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,1], color = "red", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

##############################Cp
# Creating figure Cp
fig = plt.figure(figsize = (8, 6))
visual_split = plt.axes(projection ="3d")
 
# Creating plot
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
visual_split.scatter3D(scaler.inverse_transform(X_test)[:,0], scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "g", alpha=0.6, label='Ground Truth')
plt.title("Cp Prediction vs Ground Truth")
plt.xlabel('Mach Number')
plt.ylabel('Angle of Attack')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,0], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,0], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('Mach Number')
plt.ylabel('Cd')
plt.title('Cd vs Mach Number')
plt.legend()
plt.show()

plt.scatter(scaler.inverse_transform(X_test)[:,1], predictions[:,2], color = "black", alpha=1, label='Predictions', marker='x')
plt.scatter(scaler.inverse_transform(X_test)[:,1], y_test[:,2], color = "green", alpha=0.6, label='Ground Truth')
plt.xlabel('AoA')
plt.ylabel('Cd')
plt.title('Cd vs AoA')
plt.legend()
plt.show()

# %% [markdown]
# ### Sampling Predictions

# %%
sample_number = 6
#alldata=len(predictions)
print("[Cl Cd Cp]")
for i in range (sample_number):
    print(f"Sample Data {i+1}: {y_test[i]}")
    print(f"Prediction {i+1}: {predictions[i]}")
    error = np.abs(y_test[i]-predictions[i])
    print(f"error: {error}\n--------------------------------------------------")
# Out:
# [Cl Cd Cp]
# Sample Data 1: [0.36153903 0.09598955 0.87063747]
# Prediction 1: [0.3671067  0.09727363 0.86519986]
# error: [0.00556767 0.00128408 0.0054376 ]
# --------------------------------------------------
# Sample Data 2: [0.58726315 0.36144336 0.23211893]
# Prediction 2: [0.5935321  0.35336396 0.2301263 ]
# error: [0.00626893 0.0080794  0.00199262]
# --------------------------------------------------
# Sample Data 3: [0.3266233  0.12885717 0.95581356]
# Prediction 3: [0.3315383  0.13339147 0.9518688 ]
# error: [0.00491499 0.0045343  0.00394479]
# --------------------------------------------------
# Sample Data 4: [0.22736891 0.06865012 0.89208188]
# Prediction 4: [0.22793753 0.07079916 0.88695234]
# error: [0.00056863 0.00214904 0.00512953]
# --------------------------------------------------
# Sample Data 5: [0.53716041 0.43361142 0.16522608]
# Prediction 5: [0.54001963 0.43794134 0.16957681]
# error: [0.00285922 0.00432992 0.00435073]
# --------------------------------------------------
# Sample Data 6: [0.5610469  0.48175696 0.15334601]
# Prediction 6: [0.5660691  0.4887036  0.15789032]
# error: [0.00502222 0.00694665 0.00454431]
# --------------------------------------------------
